# %% [markdown]
# # Pandas и присоединение таблиц

# %%
import pandas as pd

# %%
# Прописываем пути к файлам
bronzefpth = os.path.join('data','medals','Bronze.csv')
silverfpth = os.path.join('data','medals','Silver.csv')
goldfpth = os.path.join('data','medals','Gold.csv')
# Подгружаем CSV
bronze = pd.read_csv(bronzefpth).head(5)
silver = pd.read_csv(silverfpth).head(5)
gold = pd.read_csv(goldfpth).head(5)
gold
# Out:
#    NOC         Country   Total
# 0  USA   United States  2088.0
# 1  URS    Soviet Union   838.0
# 2  GBR  United Kingdom   498.0
# 3  FRA          France   378.0
# 4  GER         Germany   407.0

# %%
silver
# Out:
#    NOC         Country   Total
# 0  USA   United States  1195.0
# 1  URS    Soviet Union   627.0
# 2  GBR  United Kingdom   591.0
# 3  FRA          France   461.0
# 4  GER         Germany   350.0

# %%
bronze
# Out:
#    NOC         Country   Total
# 0  USA   United States  1052.0
# 1  URS    Soviet Union   584.0
# 2  GBR  United Kingdom   505.0
# 3  FRA          France   475.0
# 4  GER         Germany   454.0

# %%
medals = gold.copy()
new_labels = ['NOC', 'Country', 'Gold']
medals.columns = new_labels
medals['Silver'] = silver['Total']
medals['Bronze'] = bronze['Total']

# %%
medals.head()
# Out:
#    NOC         Country    Gold  Silver  Bronze
# 0  USA   United States  2088.0  1195.0  1052.0
# 1  URS    Soviet Union   838.0   627.0   584.0
# 2  GBR  United Kingdom   498.0   591.0   505.0
# 3  FRA          France   378.0   461.0   475.0
# 4  GER         Germany   407.0   350.0   454.0

# %%
# Когда мы хотим слить несколько табиц с одинаковыми колонками в одну большую (по вертикали)
medals_dict = {'gold': goldfpth, 'silver': silverfpth,'bronze':bronzefpth}

# %%
# Можно использовать метод df.append()
# !!! Важно, что он работает не так как append в списках, то есть не inplace
medals_df = pd.DataFrame()
for medal, fpth in medals_dict.items():
    df_temp = pd.read_csv(fpth)
    df_temp['medal'] = medal
    medals_df = medals_df.append(df_temp)

# %% [markdown]
# # Практическая часть

# %%
# Даны 3 таблицы
medalists = pd.read_csv('data/Summer Olympic medalists 1896 to 2008 - ALL MEDALISTS.tsv',
                        sep='\t', skiprows=4)
editions = pd.read_csv('data/Summer Olympic medalists 1896 to 2008 - EDITIONS.tsv', sep='\t')
countries = pd.read_csv('data/Summer Olympic medalists 1896 to 2008 - IOC COUNTRY CODES.csv')

# %%
# countries.head(3)
# editions.head(3)
# medalists.head(3)

# %%
# Определите гендерное распределение (в процентах) медалистов по странам по годам 
# Выведите результаты в виде таблицы вместе с полем ISO code
#----- Ваш код здесь ----

# %% [markdown]
# # Немного про Pandas & Excel

# %% [markdown]
# <img src='img\batman_xl.jpg' width=400 align=left>

# %%
# Сохраним medals_df в файл excel
medals_df.to_excel('medals.xlsx', index=False)

# %%
# Если в excel - файле только один лист, или нужен только первый
df = pd.read_excel('medals.xlsx')
df.head()
# Out:
#    NOC         Country   Total medal
# 0  USA   United States  2088.0  gold
# 1  URS    Soviet Union   838.0  gold
# 2  GBR  United Kingdom   498.0  gold
# 3  FRA          France   378.0  gold
# 4  GER         Germany   407.0  gold

# %%
# Если нужно считать несколько листов из файла, то 
# можно использовать pd.read_excel c параметром sheet_name 
xls = pd.ExcelFile('medals.xlsx')
xls.sheet_names
# Out:
# ['Лист1', 'Лист3', 'Лист2']

# %%
medals_from_excel = pd.DataFrame()
for sheet_name in xls.sheet_names:
    temp_df = pd.read_excel('medals.xlsx', sheet_name=sheet_name)
    medals_from_excel= medals_from_excel.append(temp_df)

# medals_from_excel

# %% [markdown]
# ### Как сохранить DataFrame в ексель на разных листах?

# %%
# Создаем файл
writer = pd.ExcelWriter('medal_on_sheets.xlsx', engine='xlsxwriter')
# Записываем на листы
gold.to_excel(writer, sheet_name='gold', index=False)
silver.to_excel(writer, sheet_name='silver', index=False)
bronze.to_excel(writer, sheet_name='bronze', index=False)
# Сохраняем и закрвыаем 
writer.save()

# %%
# Или так c помощью менеджера контекста with
with pd.ExcelWriter('medal_on_sheets.xlsx', engine='xlsxwriter') as writer:
    for i, tab in enumerate([gold,silver,bronze]):
        tab.to_excel(writer, sheet_name=str(i), index=False)

# %% [markdown]
# # Практическая часть

# %%
# Сохраните DataFrame medalists в файл medalists.xlsx
# В этом файле данные по каждой строне должны быть на отдельном листе
#----- Ваш код здесь ----

# %% [markdown]
# # Pandas & ...

# %% [markdown]
# <img src="img\web_scrap.jpeg" width=500 align=left>

# %%
import pandas as pd
import requests
from tqdm.auto import tqdm

# %%
headers = {'X-Requested-With': 'XMLHttpRequest'}
payload = ({'region':'77'})
url = 'http://www.rosneft-azs.ru/map_search'
r = requests.post(url, data=payload, headers=headers)
res = r.json()

# %%
stations = res['stations']

# %%
stations
# Out:
# [{'id': 56505,
#   'name': 'Новосибирскнефтепродукт',
#   'brand': 0,
#   'rename_fora': 0,
#   'floating': 0,
#   'address': 'Новосибирская обл., г. Новосибирск, ул. Фабричная, 4а, справа',
#   'region_code': 54,
#   'contacts': '',
#   'email': '',
#   'lat': 55.015812,
#   'lng': 82.92216,
#   'services': {'shop': 0,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 1,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 43.3, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 46.25, 'fora': 0},
#    {'available': 0, 'type': '95_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 51.5, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '1296'},
#  {'id': 58520,
#   'name': 'РН-Ростовнефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Ростовская обл., Мясниковский р-н, п. Чалтырь, а/д М23, 9 км, слева',
#   'region_code': 61,
#   'contacts': '',
#   'email': '',
#   'lat': 47.26534,
#   'lng': 39.58035,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 1},
#   'price': [{'available': 1, 'type': 92, 'price': 45.44, 'fora': 45.94},
#    {'available': 1, 'type': '92_fora', 'price': 45.94, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 0, 'fora': 50.44},
#    {'available': 1, 'type': '95_fora', 'price': 50.44, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.75, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '66448'},
#  {'id': 58316,
#   'name': 'Рязаньнефтепродукт',
#   'brand': 1,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Владимирская обл., Судогодский р-н, д. Лаврово, а/д Р72 (Владимир-Муром-Арзамас), 34 км, слева',
#   'region_code': 62,
#   'contacts': '',
#   'email': '',
#   'lat': 55.97445,
#   'lng': 40.84343,
#   'services': {'shop': 0,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 1,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 43.6, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 46.9, 'fora': 47.4},
#    {'available': 1, 'type': '95_fora', 'price': 47.4, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.4, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '1808'},
#  {'id': 58519,
#   'name': 'РН-Ростовнефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Ростовская обл., г. Ростов-на-Дону, ул. 40 Лет Победы, 2Г/51',
#   'region_code': 61,
#   'contacts': '',
#   'email': '',
#   'lat': 47.233104,
#   'lng': 39.786494,
#   'services': {'shop': 0,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 1,
#    'visa': 1},
#   'price': [{'available': 1, 'type': 92, 'price': 45.44, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 49.74, 'fora': 50.44},
#    {'available': 1, 'type': '95_fora', 'price': 50.44, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.75, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '1808'},
#  {'id': 58509,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Калужская обл., г. Калуга, ул. Зерновая, 34',
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 54.542662,
#   'lng': 36.300109,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 46, 'fora': 46.8},
#    {'available': 1, 'type': '95_fora', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.65, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58511,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': "Калужская обл., Боровский р-н, г. Балабаново, а/д МЗ 'Украина' (Москва - Калуга - Брянск - граница с Украиной), 96 км, слева",
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 55.17562,
#   'lng': 36.67466,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 46.15, 'fora': 46.95},
#    {'available': 1, 'type': '95_fora', 'price': 46.95, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.1, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58496,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Калужская обл., Дзержинский р-н, п. Полотняный Завод, а/д Р93 (Калуга - Медынь), 35 км, слева',
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 54.724663,
#   'lng': 35.989597,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.5, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 45.95, 'fora': 46.75},
#    {'available': 1, 'type': '95_fora', 'price': 46.75, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58510,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': "Калужская обл., Боровский р-н, г. Балабаново, а/д МЗ 'Украина' (Москва - Калуга - Брянск - граница с Украиной), 96 км, справа",
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 55.17559,
#   'lng': 36.67285,
#   'services': {'shop': 1,
#    'cafe': 1,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 46.15, 'fora': 46.95},
#    {'available': 1, 'type': '95_fora', 'price': 46.95, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.1, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '198416'},
#  {'id': 58502,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': "Калужская обл., Жиздринский р-н, п. Зикеево, а/д МЗ 'Украина' (Москва - Калуга - Брянск - граница с Украиной), 301 км, слева",
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 53.7484,
#   'lng': 34.80888,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 45.95, 'fora': 46.75},
#    {'available': 1, 'type': '95_fora', 'price': 46.75, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58497,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Калужская обл., г. Калуга, ул. Киевка, 2А',
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 54.515435,
#   'lng': 36.302239,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 46, 'fora': 46.8},
#    {'available': 1, 'type': '95_fora', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.65, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58503,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Калужская обл., Кировский р-н, г. Киров, ул. Калинина, 2',
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 54.078021,
#   'lng': 34.283348,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 46.05, 'fora': 46.85},
#    {'available': 1, 'type': '95_fora', 'price': 46.85, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58504,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Калужская обл., Медынский р-н, г. Медынь, а/д А101 (Калужское ш.), 158 км, справа',
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 54.966724,
#   'lng': 35.89557,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 45.95, 'fora': 46.75},
#    {'available': 1, 'type': '95_fora', 'price': 46.75, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58505,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Калужская обл., г. Калуга, ш. Грабцевское, 27',
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 54.522135,
#   'lng': 36.28476,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 46, 'fora': 46.8},
#    {'available': 1, 'type': '95_fora', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.65, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58506,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Калужская обл., г. Калуга, д Анненки, ул. Анненки, 49',
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 54.53749,
#   'lng': 36.158241,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 46, 'fora': 46.8},
#    {'available': 1, 'type': '95_fora', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.65, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58507,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': "Калужская обл., Думиничский р-н, с. Плоцкое, а/д МЗ 'Украина' (Москва - Калуга - Брянск - граница с Украиной), 274 км, слева",
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 53.95745,
#   'lng': 35.0309,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 45.95, 'fora': 46.75},
#    {'available': 1, 'type': '95_fora', 'price': 46.75, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58508,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Калужская обл., г. Калуга, ул. Салтыкова-Щедрина, 76, к.2',
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 54.49912,
#   'lng': 36.289636,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 46, 'fora': 46.8},
#    {'available': 1, 'type': '95_fora', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'diesel', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67328'},
#  {'id': 58526,
#   'name': 'РН-Ростовнефтепродукт',
#   'brand': 0,
#   'rename_fora': 0,
#   'floating': 0,
#   'address': 'Ростовская обл., г. Ростов-на-Дону, ул. Нансена, 81А',
#   'region_code': 61,
#   'contacts': '',
#   'email': '',
#   'lat': 47.246034,
#   'lng': 39.686948,
#   'services': {'shop': 0,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 1,
#    'visa': 1},
#   'price': [{'available': 1, 'type': 92, 'price': 45.44, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 49.74, 'fora': 0},
#    {'available': 0, 'type': '95_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.75, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '1296'},
#  {'id': 58253,
#   'name': 'РН-Москва',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Ленинский р-н, д. Картамазово, ш. Киевское, 23 км, слева',
#   'region_code': 77,
#   'contacts': '',
#   'email': '',
#   'lat': 55.61809,
#   'lng': 37.39129,
#   'services': {'shop': 0,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 1,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 44.4, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 48.9, 'fora': 49.9},
#    {'available': 1, 'type': '95_fora', 'price': 49.9, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 1, 'type': '100_pulsar', 'price': 55.7, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 48.4, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '1840'},
#  {'id': 58255,
#   'name': 'РН-Москва',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Ленинский р-н, д. Картамазово, ш. Киевское, 23 км, справа',
#   'region_code': 77,
#   'contacts': '',
#   'email': '',
#   'lat': 55.61895,
#   'lng': 37.39019,
#   'services': {'shop': 0,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 1,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 44.4, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 48.9, 'fora': 49.9},
#    {'available': 1, 'type': '95_fora', 'price': 49.9, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 1, 'type': '100_pulsar', 'price': 55.7, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 48.4, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '1840'},
#  {'id': 58256,
#   'name': 'РН-Москва',
#   'brand': 1,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'г. Москва, ш. Каширское, 61 к.5',
#   'region_code': 77,
#   'contacts': '',
#   'email': '',
#   'lat': 55.61251,
#   'lng': 37.7175,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 1,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 1,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 44.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 49.3, 'fora': 50.3},
#    {'available': 1, 'type': '95_fora', 'price': 50.3, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 48.9, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {},
#   'last_update': '30.03.2021',
#   'mask': '100112'},
#  {'id': 58257,
#   'name': 'РН-Москва',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'г. Москва, ш. Варшавское, 132А стр.1',
#   'region_code': 77,
#   'contacts': '',
#   'email': '',
#   'lat': 55.61666,
#   'lng': 37.61085,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 1,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 1,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 44.9, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 49.4, 'fora': 50.4},
#    {'available': 1, 'type': '95_fora', 'price': 50.4, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 48.8, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '100112'},
#  {'id': 58254,
#   'name': 'РН-Москва',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Московская обл., Люберецкий р-н, г. Люберцы, ул. Инициативная, 3А',
#   'region_code': 77,
#   'contacts': '',
#   'email': '',
#   'lat': 55.68653,
#   'lng': 37.89245,
#   'services': {'shop': 1,
#    'cafe': 1,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 1,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 43.9, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 48.4, 'fora': 49.4},
#    {'available': 1, 'type': '95_fora', 'price': 49.4, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 1, 'type': '100_pulsar', 'price': 55.7, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 48.3, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '198448'},
#  {'id': 58517,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Калужская обл., г. Калуга, ул. Железняки, 31',
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 54.54774,
#   'lng': 36.246894,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 46, 'fora': 46.8},
#    {'available': 1, 'type': '95_fora', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.65, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58512,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Калужская обл., г. Калуга, ул. Московская, 344',
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 54.594635,
#   'lng': 36.25793,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 46, 'fora': 46.8},
#    {'available': 1, 'type': '95_fora', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.65, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58513,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Калужская обл., Куйбышевский р-н, д. Кузьминичи, а/д А101 (Калужское ш.), 322 км, слева',
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 54.237129,
#   'lng': 33.721134,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.5, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 45.95, 'fora': 46.75},
#    {'available': 1, 'type': '95_fora', 'price': 46.75, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58514,
#   'name': 'Калуганефтепродукт',
#   'brand': 1,
#   'rename_fora': 0,
#   'floating': 0,
#   'address': "Калужская обл., п. Сосновый Бор, а/д МЗ 'Украина' (Москва - Калуга - Брянск - граница с Украиной), 176 км (д.11), слева",
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 54.570038,
#   'lng': 36.055562,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.7, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 45.95, 'fora': 0},
#    {'available': 0, 'type': '95_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {},
#   'last_update': '30.03.2021',
#   'mask': '66832'},
#  {'id': 58515,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': "Калужская обл., Думиничский р-н, д. Высокое, а/д МЗ 'Украина' (Москва - Калуга - Брянск - граница с Украиной), 281 км, справа",
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 53.905272,
#   'lng': 34.953526,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 45.95, 'fora': 46.75},
#    {'available': 1, 'type': '95_fora', 'price': 46.75, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58516,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Калужская обл., г. Калуга, ш. Грабцевское, нефтебаза, 178Б',
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 54.541932,
#   'lng': 36.320209,
#   'services': {'shop': 1,
#    'cafe': 1,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 45.75, 'fora': 46.55},
#    {'available': 1, 'type': '95_fora', 'price': 46.55, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.65, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '198416'},
#  {'id': 58493,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Калужская обл., Боровский р-н, г. Боровск, ул. Коммунистическая, 1',
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 55.218466,
#   'lng': 36.515154,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 46.15, 'fora': 46.95},
#    {'available': 1, 'type': '95_fora', 'price': 46.95, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 46.8, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '67344'},
#  {'id': 58494,
#   'name': 'Калуганефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': "Калужская обл., г. Обнинск, а/д МЗ 'Украина' (Москва - Калуга - Брянск - граница с Украиной), 104 км, справа",
#   'region_code': 40,
#   'contacts': '',
#   'email': '',
#   'lat': 55.10556,
#   'lng': 36.64047,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 42.8, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 46.15, 'fora': 46.95},
#    {'available': 1, 'type': '95_fora', 'price': 46.95, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.1, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
# ...
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 44.6, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 48.3, 'fora': 0},
#    {'available': 0, 'type': '95_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.1, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '1296'},
#  {'id': 56072,
#   'name': 'Липецкнефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Липецкая обл., Грязинский р-н, г. Грязи, ул. Набережная, слева',
#   'region_code': 48,
#   'contacts': '',
#   'email': '',
#   'lat': 52.499242,
#   'lng': 39.955706,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 44.6, 'fora': 45.1},
#    {'available': 1, 'type': '92_fora', 'price': 45.1, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 48.3, 'fora': 0},
#    {'available': 0, 'type': '95_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.1, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '66960'},
#  {'id': 56071,
#   'name': 'Липецкнефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Липецкая обл., г. Липецк, ул. 2-я Индустриальная, вл.19',
#   'region_code': 48,
#   'contacts': '',
#   'email': '',
#   'lat': 52.585898,
#   'lng': 39.555515,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 44.6, 'fora': 45.1},
#    {'available': 1, 'type': '92_fora', 'price': 45.1, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 48.3, 'fora': 0},
#    {'available': 0, 'type': '95_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.1, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '66960'},
#  {'id': 56068,
#   'name': 'Липецкнефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': "Липецкая обл., Становлянский р-н, с. Становое, а/д М4 'Дон' (старая), 359 км, слева",
#   'region_code': 48,
#   'contacts': '',
#   'email': '',
#   'lat': 52.762959,
#   'lng': 38.323533,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 44.6, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 48.3, 'fora': 0},
#    {'available': 0, 'type': '95_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.1, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '66832'},
#  {'id': 56065,
#   'name': 'Липецкнефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Липецкая обл., г. Липецк, ул. Гагарина, 112, справа',
#   'region_code': 48,
#   'contacts': '',
#   'email': '',
#   'lat': 52.62269,
#   'lng': 39.557026,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 44.6, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 48.3, 'fora': 0},
#    {'available': 0, 'type': '95_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.1, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '66832'},
#  {'id': 56066,
#   'name': 'Липецкнефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Липецкая обл., Хлевенский р-н, с. Хлевное, ул. Дорожная, 23',
#   'region_code': 48,
#   'contacts': '',
#   'email': '',
#   'lat': 52.191147,
#   'lng': 39.110265,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 44.6, 'fora': 45.1},
#    {'available': 1, 'type': '92_fora', 'price': 45.1, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 48.3, 'fora': 0},
#    {'available': 0, 'type': '95_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 48.2, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '66960'},
#  {'id': 56067,
#   'name': 'Липецкнефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Липецкая обл., Чаплыгинский р-н, с. Кривополянье, а/д Липецк - Чаплыгин, слева',
#   'region_code': 48,
#   'contacts': '',
#   'email': '',
#   'lat': 53.202153,
#   'lng': 39.939271,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 44.6, 'fora': 45.1},
#    {'available': 1, 'type': '92_fora', 'price': 45.1, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 48.3, 'fora': 0},
#    {'available': 0, 'type': '95_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.1, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '66960'},
#  {'id': 56069,
#   'name': 'Липецкнефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Липецкая обл., г. Липецк, а/д Р119 (Орёл-Тамбов), 288 км + 700м, слева',
#   'region_code': 48,
#   'contacts': '',
#   'email': '',
#   'lat': 52.660371,
#   'lng': 39.634859,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 44.6, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 48.3, 'fora': 0},
#    {'available': 0, 'type': '95_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.1, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '66832'},
#  {'id': 56070,
#   'name': 'Липецкнефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Липецкая обл., Долгоруковский р-н, с. Долгоруково, ул. Карла Маркса, 25 а, слева',
#   'region_code': 48,
#   'contacts': '',
#   'email': '',
#   'lat': 52.33169,
#   'lng': 38.33082,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 44.6, 'fora': 0},
#    {'available': 0, 'type': '92_fora', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 48.3, 'fora': 0},
#    {'available': 0, 'type': '95_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.1, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '66832'},
#  {'id': 56064,
#   'name': 'Липецкнефтепродукт',
#   'brand': 0,
#   'rename_fora': 1,
#   'floating': 0,
#   'address': 'Липецкая обл., Лебедянский р-н, сл. Покрово-Казацкая, ул. 1-е Пушкари, слева',
#   'region_code': 48,
#   'contacts': '',
#   'email': '',
#   'lat': 53.00887,
#   'lng': 39.18125,
#   'services': {'shop': 1,
#    'cafe': 0,
#    'wash': 0,
#    'tire': 0,
#    'hotel': 0,
#    'yagas': 0,
#    'visa': 0},
#   'price': [{'available': 1, 'type': 92, 'price': 44.6, 'fora': 45.1},
#    {'available': 1, 'type': '92_fora', 'price': 45.1, 'fora': 0},
#    {'available': 1, 'type': 95, 'price': 48.3, 'fora': 0},
#    {'available': 0, 'type': '95_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '95_jet', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 98, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '98_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 100, 'price': 0, 'fora': 0},
#    {'available': 0, 'type': '100_pulsar', 'price': 0, 'fora': 0},
#    {'available': 1, 'type': 'diesel', 'price': 47.1, 'fora': 0},
#    {'available': 0, 'type': 'diesel_fora', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'gas', 'price': 0, 'fora': 0},
#    {'available': 0, 'type': 'methane', 'price': 0, 'fora': 0}],
#   'schedule': {'mon': {'start': '', 'end': '', 'available': 0},
#    'tue': {'start': '', 'end': '', 'available': 0},
#    'wed': {'start': '', 'end': '', 'available': 0},
#    'thu': {'start': '', 'end': '', 'available': 0},
#    'fri': {'start': '', 'end': '', 'available': 0},
#    'sut': {'start': '', 'end': '', 'available': 0},
#    'sun': {'start': '', 'end': '', 'available': 0}},
#   'last_update': '30.03.2021',
#   'mask': '66960'},
#  ...]

# %%
# Формируем словарь со списками для колонок таблицы
adict = {'Azs':[],'Address' :[],'Price92':[],'Price95':[]}
# Заполняем списки с помощью цикла
for station in tqdm(stations):     
    adict['Azs'].append(station['id'])
    adict['Address'].append(station['address'])
    for d in station['price']:
        if d['type'] == 92:
            adict['Price92'].append(d['price'])
        elif d['type'] == 95:
            adict['Price95'].append(d['price'])
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2350.0), HTML(value='')))

# %%
rn = pd.DataFrame.from_dict(adict)
rn.head()
# Out:
#      Azs                                            Address  Price92  Price95
# 0  56505  Новосибирская обл., г. Новосибирск, ул. Фабрич...    43.30    46.25
# 1  58520  Ростовская обл., Мясниковский р-н, п. Чалтырь,...    45.44     0.00
# 2  58316  Владимирская обл., Судогодский р-н, д. Лаврово...    43.60    46.90
# 3  58519  Ростовская обл., г. Ростов-на-Дону, ул. 40 Лет...    45.44    49.74
# 4  58509        Калужская обл., г. Калуга, ул. Зерновая, 34    42.80    46.00

# %% [markdown]
# # Практическая часть..

# %%
# Добавить в таблицу другие виды топлива
#----- Ваш код здесь ----

# %%
# Отделить регионы от адреса АЗС
#----- Ваш код здесь ----

# %%
# Выбрать АЗС из Белоруссии и сохранить в rnbelarus
#----- Ваш код здесь ----

# %%
# Пересчитать цены rnbelarus в рубли
#----- Ваш код здесь ----

# %%
# Убрать АЗС из Белоруссии из таблциы rn
#----- Ваш код здесь ----

# %%
# Расчитать средние цены на топливо по регионам
#----- Ваш код здесь ----

# %%
# Создать директорию regional_prices
#----- Ваш код здесь ----

# %%
# Записать в отдельный .csv файл цены для каждого региона. 
# Разделить должен быть знак табуляции sep='\t'
# Название файла записать как название региона, заменив пробел на _
#----- Ваш код здесь ----

# %%
# Выведите содержимое директории в переменную list_of_files
#----- Ваш код здесь ----

# %%
# Создайте словарь regional_prices и заполните его таким образом, чтобы
# ключ был название файла без .csv, а значения - список строк, счиатанных из файла
#----- Ваш код здесь ----

# %%
# Соберите таблицу rnnew из словаря regional_prices
#----- Ваш код здесь ----
